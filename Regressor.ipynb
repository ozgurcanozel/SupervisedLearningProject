# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("nyc-bicycle-counts.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                 Date                  Day  High Temp (Â°F)  \
# 0           0  2016-04-01 00:00:00  2016-04-01 00:00:00             78.1
# 1           1  2016-04-02 00:00:00  2016-04-02 00:00:00             55.0
# 2           2  2016-04-03 00:00:00  2016-04-03 00:00:00             39.9
# 3           3  2016-04-04 00:00:00  2016-04-04 00:00:00             44.1
# 4           4  2016-04-05 00:00:00  2016-04-05 00:00:00             42.1
#
#    Low Temp (Â°F) Precipitation  Brooklyn Bridge  Manhattan Bridge  \
# 0            66.0          0.01           1704.0              3126
# 1            48.9          0.15            827.0              1646
# 2            34.0          0.09            526.0              1232
# 3            33.1      0.47 (S)            521.0              1067
# 4            26.1             0           1416.0              2617
#
#    Williamsburg Bridge  Queensboro Bridge  Total
# 0               4115.0             2552.0  11497
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           210 non-null    int64
#  1   Date                 210 non-null    object
#  2   Day                  210 non-null    object
#  3   High Temp (Â°F)      210 non-null    float64
#  4   Low Temp (Â°F)       210 non-null    float64
#  5   Precipitation        210 non-null    object
#  6   Brooklyn Bridge      210 non-null    float64
#  7   Manhattan Bridge     210 non-null    int64
#  8   Williamsburg Bridge  210 non-null    float64
#  9   Queensboro Bridge    210 non-null    float64
#  10  Total                210 non-null    int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 18.2+ KB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Day', 'High Temp (Â°F)', 'Low Temp (Â°F)',
#        'Precipitation', 'Brooklyn Bridge', 'Manhattan Bridge',
#        'Williamsburg Bridge', 'Queensboro Bridge', 'Total'],
#       dtype='object')

# %%
df.drop("Unnamed: 0", axis = 1, inplace = True)

# %%
df.head()
# Out:
#                   Date                  Day  High Temp (Â°F)  Low Temp (Â°F)  \
# 0  2016-04-01 00:00:00  2016-04-01 00:00:00             78.1            66.0
# 1  2016-04-02 00:00:00  2016-04-02 00:00:00             55.0            48.9
# 2  2016-04-03 00:00:00  2016-04-03 00:00:00             39.9            34.0
# 3  2016-04-04 00:00:00  2016-04-04 00:00:00             44.1            33.1
# 4  2016-04-05 00:00:00  2016-04-05 00:00:00             42.1            26.1
#
#   Precipitation  Brooklyn Bridge  Manhattan Bridge  Williamsburg Bridge  \
# 0          0.01           1704.0              3126               4115.0
# 1          0.15            827.0              1646               2565.0
# 2          0.09            526.0              1232               1695.0
# 3      0.47 (S)            521.0              1067               1440.0
# 4             0           1416.0              2617               3081.0
#
#    Queensboro Bridge  Total
# 0             2552.0  11497
# ...

# %%
df.isnull().sum()
# Out:
# Date                   0
# Day                    0
# High Temp (Â°F)        0
# Low Temp (Â°F)         0
# Precipitation          0
# Brooklyn Bridge        0
# Manhattan Bridge       0
# Williamsburg Bridge    0
# Queensboro Bridge      0
# Total                  0
# dtype: int64

# %%
df["Precipitation"] = df["Precipitation"].str.split(" ").str[0]
df['Precipitation'] = pd.to_numeric(df['Precipitation'], errors='coerce')
df['Precipitation'] = df['Precipitation'].fillna(0).astype(int)

# %%
df.drop(["Date", "Day"], axis = 1, inplace =True)

# %%
df.head()
# Out:
#    High Temp (Â°F)  Low Temp (Â°F)  Precipitation  Brooklyn Bridge  \
# 0             78.1            66.0              0           1704.0
# 1             55.0            48.9              0            827.0
# 2             39.9            34.0              0            526.0
# 3             44.1            33.1              0            521.0
# 4             42.1            26.1              0           1416.0
#
#    Manhattan Bridge  Williamsburg Bridge  Queensboro Bridge  Total
# 0              3126               4115.0             2552.0  11497
# 1              1646               2565.0             1884.0   6922
# 2              1232               1695.0             1306.0   4759
# 3              1067               1440.0             1307.0   4335
# 4              2617               3081.0             2357.0   9471

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   High Temp (Â°F)      210 non-null    float64
#  1   Low Temp (Â°F)       210 non-null    float64
#  2   Precipitation        210 non-null    int64
#  3   Brooklyn Bridge      210 non-null    float64
#  4   Manhattan Bridge     210 non-null    int64
#  5   Williamsburg Bridge  210 non-null    float64
#  6   Queensboro Bridge    210 non-null    float64
#  7   Total                210 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 13.3 KB

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <Axes: >

# %%
sns.pairplot(data = df, hue = "Total")

# %%
X = df.drop("Total", axis = 1)
y = df["Total"]

# %%
X.head()
# Out:
#    High Temp (Â°F)  Low Temp (Â°F)  Precipitation  Brooklyn Bridge  \
# 0             78.1            66.0              0           1704.0
# 1             55.0            48.9              0            827.0
# 2             39.9            34.0              0            526.0
# 3             44.1            33.1              0            521.0
# 4             42.1            26.1              0           1416.0
#
#    Manhattan Bridge  Williamsburg Bridge  Queensboro Bridge
# 0              3126               4115.0             2552.0
# 1              1646               2565.0             1884.0
# 2              1232               1695.0             1306.0
# 3              1067               1440.0             1307.0
# 4              2617               3081.0             2357.0

# %%
print(y)
# Out:
# 0      11497
# 1       6922
# 2       4759
# 3       4335
# 4       9471
#        ...
# 205    13005
# 206    19914
# 207    15631
# 208    14954
# 209    17432
# Name: Total, Length: 210, dtype: int64

# %%
df.shape
# Out:
# (210, 8)

# %%
df.dtypes
# Out:
# High Temp (Â°F)        float64
# Low Temp (Â°F)         float64
# Precipitation            int64
# Brooklyn Bridge        float64
# Manhattan Bridge         int64
# Williamsburg Bridge    float64
# Queensboro Bridge      float64
# Total                    int64
# dtype: object

# %%
df.columns = df.columns.str.replace("Â°F", "F")
df.columns = df.columns.str.replace(" ", "_")
df.columns = df.columns.str.replace("(", "")
df.columns = df.columns.str.replace(")", "")

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=15)
